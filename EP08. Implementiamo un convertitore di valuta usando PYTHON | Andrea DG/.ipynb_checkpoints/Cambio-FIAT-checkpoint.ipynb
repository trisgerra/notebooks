# %% [markdown]
# # Costruiamo un Convertitore di valuta

# %% [markdown]
# ### Installiamo requests per fare delle richiest HTTP
# Ci permette di scaricare dati sui vari cambi da internet utilizzando un servizio chiamato frankfurter

# %%
# !pip install requests

# %% [markdown]
# ### Importiamo la libreria per utilizzarla nel nostro notebook

# %%
import requests

# %% [markdown]
# ### Dopo averla importata possiamo utilizzarla:
#  eseguiamo una richiesta HTTP GET per ricevere i dati

# %%
r = requests.get("https://api.frankfurter.dev/v1/latest")
json = r.json()
print(f"Risposta JSON: {json}")
type(json)
# print(f"Accediamo a rates : {json["rates"]}")

# %%
enumerate?

# %%
enumer = enumerate([
    "EUR/USD",
    "EUR/GBP",
    "EUR/CHF",
    "EUR/CAD",
    "EUR/AUD"
], start=1)
print(list(enumer))

# %%
a = input("test")
type(a)

# %%
"Ciao/Sono/Andrea".split("/")

# %%
import requests
response = requests.get("https://api.frankfurter.dev/v1/latest")
interested_changes = [f"EUR/{rate}" for rate in response.json()["rates"].keys()]

# print(interested_changes)
selected_change: str = ""

print("\nSeleziona il cambio valuta desiderato:")
for index, interest_change in enumerate(interested_changes, start=1):
    print(f"{index}. {interest_change}")    
print("Scrivi \"esci\" per terminare")

while True:
    change = input("Inserisci il valore desiderato: ")
    if change == "esci":
        break
    else:
        selected_change = interested_changes[int(change) - 1]
        selected_rate_key = selected_change.split("/")[1]
        print(f"Il valore di cambio per {selected_change} e': {rates.get(selected_rate_key, "N/A")}", end="\n\n**********")
# Out:
# Seleziona il cambio valuta desiderato:
# 1. EUR/AUD
# 2. EUR/BGN
# 3. EUR/BRL
# 4. EUR/CAD
# 5. EUR/CHF
# 6. EUR/CNY
# 7. EUR/CZK
# 8. EUR/DKK
# 9. EUR/GBP
# 10. EUR/HKD
# 11. EUR/HUF
# 12. EUR/IDR
# 13. EUR/ILS
# 14. EUR/INR
# 15. EUR/ISK
# 16. EUR/JPY
# 17. EUR/KRW
# 18. EUR/MXN
# 19. EUR/MYR
# 20. EUR/NOK
# 21. EUR/NZD
# 22. EUR/PHP
# 23. EUR/PLN
# 24. EUR/RON
# 25. EUR/SEK
# 26. EUR/SGD
# 27. EUR/THB
# 28. EUR/TRY
# 29. EUR/USD
# 30. EUR/ZAR
# Scrivi "esci" per terminare
# Inserisci il valore desiderato:  1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      18 selected_change = interested_changes[int(change) - 1]
#      19 selected_rate_key = selected_change.split("/")[1]
# ---> 20 print(f"Il valore di cambio per {selected_change} e': {rates.get(selected_rate_key, "N/A")}", end="\n\n**********")
#
# NameError: name 'rates' is not defined

# %% [markdown]
# ### Disinstalliamo requests alla fine

# %%
# !pip uninstall -y requests
